# %%
import pandas as pd
from glob import iglob
import numpy as np
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt


def getDataFromCsv(absolutPath ,dirName, fields):
    path = r'{}\{}\*.csv'.format(absolutPath, dirName)
    return pd.concat((pd.read_csv(f,skipinitialspace=True, usecols=fields) for f in iglob(path, recursive=True)), ignore_index=True)

#def removeOutliers(dataFrame):
#    z = np.abs(stats.zscore(dataFrame))
#    return dataFrame[(z<3)]

def removeOutliers(dataFrame):
    z = np.abs(stats.zscore(dataFrame['elapsed']))
    return dataFrame[(z<3)]

def getCallbackDir(dirName, callBack):
    return r'{}\{}'.format(dirName, callBack)

absolutPath = r'D:\gabriel\Uni\Master\gitHub\micro-cocome-statistics\measurements'
callBack = r'callBack'

ag1to1 = r'api_gateway_1_to_1_db_distributed'
agOne = r'api_gateway_one_db_distributed'
m1to1 = r'master_1_to_1_db_distributed'
mOne = r'master_one_db_distributed'
oAg1to1 = r'orchestrate_api_gateway_1_to_1_db_distributed'
ps1tot1 = r'pub_sub_1_to_1_db_distributed'

fields = ['elapsed']
fieldsAsync = ['elapsed', 'uuid']
    
# api_gateway_1_to_1_db    
apg1 = getDataFromCsv(absolutPath, ag1to1, fields)
prunedApg1 = removeOutliers(apg1)

sns.displot(prunedApg1, x="elapsed")
plt.title('api_gateway_1_to_1_db ')

# api_gateway_one_db 
apgOne = getDataFromCsv(absolutPath, agOne, fields)
prunedApgOne = removeOutliers(apgOne)

sns.displot(prunedApgOne, x="elapsed")
plt.title('api_gateway_one_db')

# master_1_to_1_db_distributed
master1 = getDataFromCsv(absolutPath, m1to1, fields)
prunedMaster1 = removeOutliers(master1)

sns.displot(prunedMaster1, x="elapsed")
plt.title('master_1_to_1_db')

# master_one_db_distributed
masterOne = getDataFromCsv(absolutPath, mOne, fields)
prunedMasterOne = removeOutliers(masterOne)

sns.displot(prunedMasterOne, x="elapsed")
plt.title('master_one_db')

# orchestrate_api_gateway_1_to_1_db_distributed
oApi1to1 = getDataFromCsv(absolutPath, oAg1to1, fields)
prunedOApi1to1 = removeOutliers(oApi1to1)

sns.displot(prunedOApi1to1, x="elapsed")
plt.title('orchestrate_api_gateway_1_to_1_db')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-8764049193b1> in <module>
#      73 # pub_sub_1_to_1_db_distributed
#      74 pubSub1to1 = getDataFromCsv(absolutPath, ps1tot1, fieldsAsync)
# ---> 75 pubSub1to1Callback = getDataFromCsv(absolutPath, getCallbackDir(ps1tot1,callBack), fieldsAsync)
#      76
#      77 pubSub1to1
#
# <ipython-input-101-8764049193b1> in getDataFromCsv(absolutPath, dirName, fields)
#      10 def getDataFromCsv(absolutPath ,dirName, fields):
#      11     path = r'{}\{}\*.csv'.format(absolutPath, dirName)
# ---> 12     return pd.concat((pd.read_csv(f,skipinitialspace=True, usecols=fields) for f in iglob(path, recursive=True)), ignore_index=True)
#      13
#      14 #def removeOutliers(dataFrame):
#
# ...

# %%
# pub_sub_1_to_1_db_distributed
pubSub1to1 = getDataFromCsv(absolutPath, ps1tot1, fieldsAsync)
pubSub1to1Callback = getDataFromCsv(absolutPath, getCallbackDir(ps1tot1,callBack), fieldsAsync)

pubSub1to1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-102-c10273b8d4ba> in <module>
#       1 # pub_sub_1_to_1_db_distributed
#       2 pubSub1to1 = getDataFromCsv(absolutPath, ps1tot1, fieldsAsync)
# ----> 3 pubSub1to1Callback = getDataFromCsv(absolutPath, getCallbackDir(ps1tot1,callBack), fieldsAsync)
#       4
#       5 pubSub1to1
#
# <ipython-input-101-8764049193b1> in getDataFromCsv(absolutPath, dirName, fields)
#      10 def getDataFromCsv(absolutPath ,dirName, fields):
#      11     path = r'{}\{}\*.csv'.format(absolutPath, dirName)
# ---> 12     return pd.concat((pd.read_csv(f,skipinitialspace=True, usecols=fields) for f in iglob(path, recursive=True)), ignore_index=True)
#      13
#      14 #def removeOutliers(dataFrame):
#
# ...
